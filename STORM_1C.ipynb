# %% [markdown]
# <center> <H1> Testing H1: MRGs are comparabe to nucleoids in size </H1> </center>
#
#
#                         *Code written by Timo Rey. Laboratory of Experimental Biophysics, EPFL*
#
#                                             *Created from 2019 - 2020*
#
# #### Aims:
#     To assess the dimensions and architecture of Mitochondrial RNA Granules.
#
# #### H0:
#     There are no conclusive statements possible about the size of MRGs based on our htSTORM data.
#
# #### Approach:
#     1) Load descriptors for all granules from one-colour STORM measurements.
#     2) Compare.

# %% [markdown]
# # Initialize libraries & functions

# %%
#load libraries:
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import math
from statannot import add_stat_annotation

# %%
# define column names:
cols = ['Rg', 'Ecc', 'Length', 'Width', 'Rg-half', 'k', 'Eps','ConvexHullArea','Locs']

# function to load the data:
def load_data(DATA_tot):
    file                         = directory + filename

    DATA                         = pd.read_csv(file, sep = ',', names = cols)
    DATA['Diameter']             = (DATA['Length']+DATA['Width'])
    DATA['FWHM']                 = (DATA['Diameter']*math.sqrt(2*math.log(2))) #calc. average FWHM from average sigma [FWHM = 2*sqrt(2ln(2))*sigma]
    DATA['condition']            = cond
    DATA['Density']              = (DATA['Locs']/DATA['ConvexHullArea'])
 
    DATA_tot                      = pd.concat([DATA_tot, DATA])
    
    return DATA_tot

def plot_stats(value, testtype):
    # create figure:
    f, axes = plt.subplots(1,1, sharex = False, figsize=(6, 10))
    
    # plot boxplots:
    sns.boxplot(data = DATA_tot, x = "condition", y = value, order = sorter, palette=palette)
    # add significance indicators:
    add_stat_annotation(axes, data=DATA_tot, x = "condition", y = value, order=sorter,
                    box_pairs = box_pairs,
                    test=testtype, text_format='star', loc='inside', verbose=2)
    
    # plot all data-points:
    sns.swarmplot(data = DATA_tot, x = "condition", y = value,  size=3, color="grey", alpha=1, linewidth=0)
    
def plot_stats_data(df, value, testtype):
    # create figure:
    f, axes = plt.subplots(1,1, sharex = False, figsize=(6, 10))
    
    # plot boxplots:
    sns.boxplot(data = df, x = "condition", y = value, order = sorter, palette=palette)
    # add significance indicators:
    add_stat_annotation(axes, data=df, x = "condition", y = value, order=sorter,
                    box_pairs = box_pairs,
                    test=testtype, text_format='star', loc='inside', verbose=2)
    
    # plot all data-points:
    sns.swarmplot(data = df, x = "condition", y = value,  size=3, color="grey", alpha=1, linewidth=0)
    # create legend:
    labels = []
    for i in sorter:
        newlabel = "%s: %r nm; n = %r" %(i, round(DATA_tot[DATA_tot["condition"] == i][value].median(), 1), len(DATA_tot[DATA_tot["condition"] == i]))
        labels.append(newlabel)
    # plot legend:
    axes.legend(labels)

# %%
# clean the variables:
DATA_tot                          = None

# %%
# give basic path:
base_dir = 'C:/Users/Public/Documents/03_Architecture/01_STORM_1C/'

# %% [markdown]
# # Load data

# %% [markdown]
# ### BrU

# %%
Probe = '1hBrU'
cond = 'mtRNA'

# %%
# 07.09.2018
Date  = '20180907'

directory = base_dir + 'COS7_' + Probe + '_' + Date + '/Analysis/filtered_MRGs/'
filename  = 'COS7_'+Probe+'_'+Date+'.csv'
DATA_tot  = load_data(DATA_tot)

# %%
# 13.09.2018
Date  = '20180913'

directory = base_dir + 'COS7_' + Probe + '_' + Date + '/Analysis/filtered_MRGs/'
filename  = 'COS7_'+Probe+'_'+Date+'.csv'
DATA_tot  = load_data(DATA_tot)

# %%
# 08.11.2018
Date  = '20181108'

directory = base_dir + 'COS7_' + Probe + '_' + Date + '/Analysis/filtered_MRGs/'
filename  = 'COS7_'+Probe+'_'+Date+'.csv'
DATA_tot  = load_data(DATA_tot)

# %%
# 14.11.2019
Date  = '20191114'

directory = base_dir + 'COS7_' + Probe + '_' + Date + '/Analysis/filtered_MRGs/'
filename  = 'COS7_'+Probe+'_'+Date+'.csv'
DATA_tot  = load_data(DATA_tot)

# %%
# 12.12.2019
Date  = '20191212'

directory = base_dir + 'COS7_' + Probe + '_' + Date + '/Analysis/filtered_MRGs/'
filename  = 'COS7_'+Probe+'_'+Date+'.csv'
DATA_tot  = load_data(DATA_tot)

# %% [markdown]
# ### mtDNA

# %%
Probe = 'mtDNA'
cond = Probe

# %%
# 30.04.2019
Date  = '20190430'

directory = base_dir + 'COS7_' + Probe + '_' + Date + '/Analysis/filtered_MRGs/'
filename  = 'COS7_'+Probe+'_'+Date+'_FOVs_1-6.csv'
DATA_tot  = load_data(DATA_tot)

# %%
# 30.04.2019
Date  = '20190430'

directory = base_dir + 'COS7_' + Probe + '_' + Date + '/Analysis/filtered_MRGs/'
filename  = 'COS7_'+Probe+'_'+Date+'_FOVs_7-14.csv'
DATA_tot  = load_data(DATA_tot)

# %% [markdown]
# ### GRSF1

# %%
Probe = 'GRSF1'
cond = Probe

# %%
# 25.04.2019
Date  = '20190425'

directory = base_dir + 'COS7_' + Probe + '_' + Date + '/Analysis/filtered_MRGs/'
filename  = 'COS7_'+Probe+'_'+Date+'.csv'
DATA_tot  = load_data(DATA_tot)

# %%
# 01.05.2019
Date  = '20190501'

directory = base_dir + 'COS7_' + Probe + '_' + Date + '/Analysis/filtered_MRGs/'
filename  = 'COS7_'+Probe+'_'+Date+'.csv'
DATA_tot  = load_data(DATA_tot)

# %% [markdown]
# ### FASTKD2

# %%
Probe = 'D2'
cond = 'FASTKD2'

# %%
# 27.03.2019
Date  = '20190327'

directory = base_dir + 'COS7_' + Probe + '_' + Date + '/Analysis/filtered_MRGs/'
filename  = 'COS7_'+Probe+'_'+Date+'.csv'
DATA_tot  = load_data(DATA_tot)

# %%
# 01.05.2019
Date  = '20190501'

directory = base_dir + 'COS7_' + Probe + '_' + Date + '/Analysis/filtered_MRGs/'
filename  = 'COS7_'+Probe+'_'+Date+'.csv'
DATA_tot  = load_data(DATA_tot)

# %%
DATA_tot = DATA_tot.drop_duplicates()
len(DATA_tot)

# %% [markdown]
# # Compare and plot data

# %%
# define output directory:
outDir    = 'W:/Timo-Rey/NatureCellBiology_resubmission/Figure_1/STORM_1C/Figures_and_Plots/'

# %%
# define order
sorter             = ["mtDNA", "mtRNA", "FASTKD2", "GRSF1"]

DATA_tot.condition = DATA_tot.condition.astype("category")
DATA_tot.condition.cat.set_categories(sorter, inplace=True)
DATA_tot           = DATA_tot.sort_values("condition")

# %%
# show example:
DATA_tot[:1]

# %%
# choose statistical test:
test           = 'Mann-Whitney'

# %% [markdown]
# ### Make plots:

# %%
value          = "FWHM"
palette        = ["magenta", "cyan", "lime", "GreenYellow", "green"]
box_pairs      = [("mtRNA", "mtDNA"), ("mtRNA", "FASTKD2"), ("mtRNA", "GRSF1"), ("FASTKD2", "GRSF1")]

test           = 'Mann-Whitney'
data           = DATA_tot

plot_stats_data(data, value, test)
plt.savefig(outDir + value + '_' + test + '_2C.svg')

# %%
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# mtDNA v.s. mtRNA: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=6.530e+04
# mtRNA v.s. FASTKD2: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.007e-48 U_stat=2.283e+04
# FASTKD2 v.s. GRSF1: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=3.089e-11 U_stat=6.598e+04
# mtRNA v.s. GRSF1: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=4.467e-30 U_stat=3.763e+04

# %%
value          = "Ecc"
palette        = ["magenta", "cyan", "lime", "GreenYellow", "green"]
box_pairs      = [("mtRNA", "mtDNA"), ("mtRNA", "FASTKD2"), ("mtRNA", "GRSF1"), ("FASTKD2", "GRSF1")]

test           = 'Mann-Whitney'
data           = DATA_tot

plot_stats_data(data, value, test)
plt.savefig(outDir + value + '_' + test + '_2C.svg')

# %%
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# mtDNA v.s. mtRNA: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=6.861e+04
# mtRNA v.s. FASTKD2: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.421e-15 U_stat=8.674e+04
# FASTKD2 v.s. GRSF1: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=5.142e-03 U_stat=4.277e+04
# mtRNA v.s. GRSF1: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.716e-06 U_stat=8.830e+04

# %%
DATA_tot["Sigma"] = DATA_tot["Diameter"]

# %%
value          = "Sigma"
palette        = ["magenta", "cyan", "lime", "GreenYellow", "green"]
box_pairs      = [("mtRNA", "mtDNA"), ("mtRNA", "FASTKD2"), ("mtRNA", "GRSF1"), ("FASTKD2", "GRSF1")]

test           = 'Mann-Whitney'
data           = DATA_tot

plot_stats_data(data, value, test)
plt.savefig(outDir + value + '_' + test + '_2C.svg')

# %%
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# mtDNA v.s. mtRNA: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=6.530e+04
# mtRNA v.s. FASTKD2: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.007e-48 U_stat=2.283e+04
# FASTKD2 v.s. GRSF1: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=3.089e-11 U_stat=6.598e+04
# mtRNA v.s. GRSF1: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=4.467e-30 U_stat=3.763e+04

# %%
value          = "Rg"
palette        = ["magenta", "cyan", "lime", "GreenYellow", "green"]
box_pairs      = [("mtRNA", "mtDNA"), ("mtRNA", "FASTKD2"), ("mtRNA", "GRSF1"), ("FASTKD2", "GRSF1")]

test           = 'Mann-Whitney'
data           = DATA_tot

plot_stats_data(data, value, test)
plt.savefig(outDir + value + '_' + test + '_2C.svg')

# %%
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# mtDNA v.s. mtRNA: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=6.492e+04
# mtRNA v.s. FASTKD2: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.715e-45 U_stat=2.435e+04
# FASTKD2 v.s. GRSF1: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.747e-09 U_stat=6.459e+04
# mtRNA v.s. GRSF1: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=6.413e-28 U_stat=3.897e+04

# %%
value          = "ConvexHullArea"
palette        = ["magenta", "cyan", "lime", "GreenYellow", "green"]
box_pairs      = [("mtRNA", "mtDNA"), ("mtRNA", "FASTKD2"), ("mtRNA", "GRSF1"), ("FASTKD2", "GRSF1")]

test           = 'Mann-Whitney'
data           = DATA_tot[DATA_tot["ConvexHullArea"]<250000]

plot_stats_data(data, value, test)
plt.savefig(outDir + value + '_' + test + '_2C_skippedOutlierSmaller250000.svg')

# %%
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# mtDNA v.s. mtRNA: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.217e-06 U_stat=8.152e+04
# mtRNA v.s. FASTKD2: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.717e-61 U_stat=1.750e+04
# FASTKD2 v.s. GRSF1: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=6.852e-07 U_stat=6.186e+04
# mtRNA v.s. GRSF1: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=6.472e-49 U_stat=2.761e+04

# %%
value          = "Locs"

palette        = ["magenta", "cyan", "lime", "GreenYellow", "green"]
box_pairs      = [("mtRNA", "mtDNA"), ("mtRNA", "FASTKD2"), ("mtRNA", "GRSF1"), ("FASTKD2", "GRSF1")]

plot_stats(value, test)
plt.savefig(outDir + value + '_' + test + '_2C.svg')

# %%
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# mtDNA v.s. mtRNA: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=9.063e-18 U_stat=9.194e+04
# mtRNA v.s. FASTKD2: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.580e-54 U_stat=2.048e+04
# FASTKD2 v.s. GRSF1: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=4.930e+04
# mtRNA v.s. GRSF1: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.041e-59 U_stat=2.275e+04

# %%
value          = "Density"
palette        = ["magenta", "cyan", "lime", "GreenYellow", "green"]
box_pairs      = [("mtRNA", "mtDNA"), ("mtRNA", "FASTKD2"), ("mtRNA", "GRSF1"), ("FASTKD2", "GRSF1"), ("mtDNA","FASTKD2"), ("mtDNA", "GRSF1")]

data           = DATA_tot[DATA_tot["Density"]<0.11]

plot_stats_data(data, value, test)
plt.savefig(outDir + value + '_' + test + '_rm2outliers2C.svg')

# %%
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# mtDNA v.s. mtRNA: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.169e-07 U_stat=8.264e+04
# mtRNA v.s. FASTKD2: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=7.116e-06 U_stat=7.755e+04
# FASTKD2 v.s. GRSF1: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=7.302e-26 U_stat=2.555e+04
# mtRNA v.s. GRSF1: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=5.260e-02 U_stat=6.482e+04
# mtDNA v.s. FASTKD2: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=4.640e-34 U_stat=7.263e+04
# mtDNA v.s. GRSF1: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=7.176e-06 U_stat=6.395e+04
